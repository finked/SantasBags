# %% [markdown]
# ### Imports:

# %%
import numpy as np
from pandas.io.parsers import read_csv
import pandas as pd

# %% [markdown]
# ### Functions:

# %%
def loadData(filename):
    return read_csv(filename)

def saveGifts():
    return Null
    
def generateHorseData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = max(0, np.random.normal(5,2,1)[0])
    return data

def generateBallData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] =max(0, 1 + np.random.normal(1,0.3,1)[0])
    return data

def generateBikeData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = max(0, np.random.normal(20,10,1)[0])
    return data

def generateTrainData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = max(0, np.random.normal(10,5,1)[0])
    return data

def generateCoalData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = 47 * np.random.beta(0.5,0.5,1)[0]
    return data

def generateBookData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = np.random.chisquare(2,1)[0]
    return data

def generateDollData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = np.random.gamma(5,1,1)[0]
    return data

def generateBlockData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = np.random.triangular(5,10,20,1)[0]
    return data

def generateGloveData(number):
    data = np.zeros(number)
    for i in range(number):
        data[i] = 3.0 + np.random.rand(1)[0] if np.random.rand(1) < 0.3 else np.random.rand(1)[0]
    return data
    
def generateTestData():
    data = []
    data.append(generateHorseData(1000))
    data.append(generateBallData(1100))
    data.append(generateBikeData(500))
    data.append(generateTrainData(1000))
    data.append(generateCoalData(166))
    data.append(generateBookData(1200))
    data.append(generateDollData(1000))
    data.append(generateBlockData(1000))
    data.append(generateGloveData(200))
    return data

# %% [markdown]
# ### Read Data:

# %%
filename = "./data/gifts.csv"
fileData = loadData(filename)

# %% [markdown]
# ### Plot Data:

# %%
fileData
# Out:
#           GiftId
# 0        horse_0
# 1        horse_1
# 2        horse_2
# 3        horse_3
# 4        horse_4
# 5        horse_5
# 6        horse_6
# 7        horse_7
# 8        horse_8
# 9        horse_9
# 10      horse_10
# 11      horse_11
# 12      horse_12
# 13      horse_13
# 14      horse_14
# 15      horse_15
# 16      horse_16
# 17      horse_17
# 18      horse_18
# 19      horse_19
# 20      horse_20
# 21      horse_21
# 22      horse_22
# 23      horse_23
# 24      horse_24
# 25      horse_25
# 26      horse_26
# 27      horse_27
# 28      horse_28
# 29      horse_29
# ...          ...
# 7136  gloves_170
# 7137  gloves_171
# 7138  gloves_172
# 7139  gloves_173
# 7140  gloves_174
# 7141  gloves_175
# 7142  gloves_176
# 7143  gloves_177
# 7144  gloves_178
# 7145  gloves_179
# 7146  gloves_180
# 7147  gloves_181
# 7148  gloves_182
# 7149  gloves_183
# 7150  gloves_184
# 7151  gloves_185
# 7152  gloves_186
# 7153  gloves_187
# 7154  gloves_188
# 7155  gloves_189
# ...

# %%
test = generateTestData()
print(test[0].shape)
# Out:
# (1000,)
